# %% [markdown]
# # Analyze combined results

# %%
import pandas as pd

# Path to CSV
path = "results/combined_results/tables/processGraphsPDefaultWDefault/complexity_delta_simple.csv"

# Read CSV (first column as index)
df = pd.read_csv(path, index_col=0)

print("Available columns:")
print(df.columns.tolist())

# --- Let user select columns ---
# Example: choose specific columns
cols_to_keep = ["Instances", "Distinct traces", "Trace length avg", "Normalized Trace Entropy", "Pentland's process complexity"]
df_selected = df[cols_to_keep]

df_selected
# Out:
# Available columns:
# ['Instances', 'Affinity', 'Deviation from random', 'Distinct traces', 'Lempel-Ziv complexity', 'Level of detail', 'Magnitude', 'Normalized Trace Entropy', 'Normalized Variant Entropy', "Pentland's process complexity", "Pentland's task complexity", 'Structure', 'Support', 'Time granularity', 'Trace Entropy', 'Trace length avg', 'Trace length max', 'Trace length min', 'Variant Entropy', 'Variety']
#                             Instances Distinct traces Trace length avg  \
# Change Type
# Sudden (before to after)           82    -0.69 (7.57)     -0.52 (5.90)
# Gradual (before to after)          21    -3.07 (8.51)     -1.02 (5.60)
# Gradual (before to during)         21    -1.23 (8.88)     -0.86 (3.70)
# Gradual (during to after)          21    -1.85 (7.22)     -0.16 (3.06)
#
#                            Normalized Trace Entropy  \
# Change Type
# Sudden (before to after)               -0.01 (0.04)
# Gradual (before to after)              -0.01 (0.05)
# ...

# %%
import pandas as pd

# Path to CSV
path = "results/combined_results/tables/processGraphsPDefaultWDefault/drift_info_summary.csv"

# Read CSV (first column as index)
df = pd.read_csv(path, index_col=0)

df
# Out:
#             # Total Changes  # Sudden Changes  \
# BPIC12                   34                31
# BPIC13_cp                 1                 1
# BPIC13_i                  3                 1
# BPIC14                   14                11
# BPIC15_1                  4                 3
# BPIC15_2                  4                 4
# BPIC15_3                  4                 2
# BPIC15_4                  3                 2
# BPIC15_5                  3                 2
# BPIC20_dd                 2                 2
# BPIC20_id                 1                 0
# BPIC20_ptc                1                 1
# BPIC20_rfp                1                 1
# BPIC20_tpd                2                 0
# CALL                      2                 1
# ITHD                      1                 1
# RTFMP                    23                19
# Total                   103                82
#
#                                          Sudden Change Points  \
# ...
