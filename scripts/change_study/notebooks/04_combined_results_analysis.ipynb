# %% [markdown]
# # Analyze combined results

# %%
import pandas as pd

# Path to CSV
path = "results/combined_results/tables/processGraphsPDefaultWDefault__cp_default/complexity_delta_simple.csv"

# Read CSV (first column as index)
df = pd.read_csv(path, index_col=0)

print("Available columns:")
print(df.columns.tolist())

# --- Let user select columns ---
# Example: choose specific columns
cols_to_keep = ["Instances", "Distinct traces", "Distinct traces (full coverage)", "Distinct traces (same coverage)",  "Trace length avg", "Normalized Trace Entropy", "Pentland's process complexity"]
df_selected = df[cols_to_keep]

df_selected
# Out:
# Available columns:
# ['Instances', 'Affinity', 'Deviation from random', 'Distinct traces', 'Distinct traces (full coverage)', 'Distinct traces (same coverage)', 'Lempel-Ziv complexity', 'Level of detail', 'Magnitude', 'Normalized Trace Entropy', 'Normalized Variant Entropy', 'Pentland process complexity (full coverage)', 'Pentland process complexity (same coverage)', "Pentland's process complexity", "Pentland's task complexity", 'Structure', 'Support', 'Time granularity', 'Trace Entropy', 'Trace length avg', 'Trace length max', 'Trace length min', 'Variant Entropy', 'Variety', 'Variety (full coverage)', 'Variety (same coverage)']
#                             Instances  Distinct traces  \
# Change Type
# Sudden (before to after)          104   +7.50 (401.84)
# Gradual (before to after)          30  -30.67 (524.08)
# Gradual (before to during)         29  +52.00 (417.20)
# Gradual (during to after)          29  -85.14 (471.65)
#
# ...

# %%
import pandas as pd

# Path to CSV
path = "results/combined_results/tables/processGraphsPDefaultWDefault__cp_default/drift_info_summary.csv"

# Read CSV (first column as index)
df = pd.read_csv(path, index_col=0)

df
# Out:
#             # Total Changes  # Sudden Changes  \
# BPIC12                   34                31
# BPIC13_cp                 1                 1
# BPIC13_i                  3                 1
# BPIC14                   14                11
# BPIC15_2                  4                 4
# BPIC15_3                  4                 2
# BPIC15_4                  3                 2
# BPIC15_5                  3                 2
# BPIC17                   38                28
# BPIC20_dd                 2                 2
# BPIC20_id                 1                 0
# BPIC20_ptc                1                 1
# BPIC20_rfp                1                 1
# BPIC20_tpd                2                 0
# CALL                      2                 1
# ITHD                      1                 1
# RTFMP                    23                19
# Total                   137               107
#
#                                          Sudden Change Points  \
# ...
